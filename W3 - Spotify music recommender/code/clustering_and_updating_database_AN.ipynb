# %% [markdown]
# # Plan
#
# 1. Combine both data frames - top 100 and Spotify.
# - add column that show from which DF comes the songs
# - import both DF from other file
#
#
# 2. Remove duplicates
#
# 3. Make new DF only with numerical variables
#
# 4. standardization the new df

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import pickle

# %% [markdown]
# # Importing DF

# %%
hot_100_df = pd.read_csv('D:\Data Science\Ironhack\Week 3\Project_song_recomender\data\hot_100.csv')
spotify_df = pd.read_csv('D:\Data Science\Ironhack\Week 3\Project_song_recomender\data\spotify_df.csv')

hot_100 = hot_100_df.copy()
spotify = spotify_df.copy()

# %% [markdown]
# # Removing unnamed column

# %%
# removing unnamed: 0 column and reseting indexes

hot_100.drop(['Unnamed: 0'], axis=1, inplace=True)
spotify.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# # Adding new column with index 1 for hot_100 and index 0 for spotify

# %%
# index 1 for hot 100

origin_hot_100 = [1 for i in range(100)]

# index 0 for spotify
origin_spotify = [0 for i in range(10000)]


hot_100['origin'] = origin_hot_100
spotify['origin'] = origin_spotify

# %%
hot_100
# Out:
#                                 Title  \
# 0                              Butter
# 1                            Good 4 U
# 2                          Levitating
# 3                             Peaches
# 4                 Leave The Door Open
# ..                                ...
# 95           Things A Man Oughta Know
# 96                      Country Again
# 97  Drunk (And I Don't Wanna Go Home)
# 98                     If You Want To
# 99                       Seeing Green
#
#                                             Artist  danceability  energy  key  \
# 0                                              BTS         0.759   0.459    8
# 1                                   Olivia Rodrigo         0.563   0.664    9
# 2                        Dua Lipa Featuring DaBaby         0.708   0.796    6
# 3   Justin Bieber Featuring Daniel Caesar & Giveon         0.677   0.696    0
# 4         Silk Sonic (Bruno Mars & Anderson .Paak)         0.586   0.616    5
# ..                                             ...           ...     ...  ...
# 95                                   Lainey Wilson         0.659   0.683    3
# 96                                    Thomas Rhett         0.467   0.481    2
# 97                     Elle King & Miranda Lambert         0.612   0.884    5
# 98                             Lil Baby & Lil Durk         0.795   0.599    6
# 99                  Nicki Minaj, Drake & Lil Wayne         0.573   0.867    5
#
#     loudness  mode  speechiness  acousticness  instrumentalness  ...  valence  \
# 0     -5.187     1       0.0948       0.00323          0.000000  ...    0.695
# 1     -5.044     1       0.1540       0.33500          0.000000  ...    0.688
# 2     -4.821     0       0.0610       0.00886          0.000000  ...    0.923
# 3     -6.181     1       0.1190       0.32100          0.000000  ...    0.464
# 4     -7.964     1       0.0324       0.18200          0.000000  ...    0.719
# ..       ...   ...          ...           ...               ...  ...      ...
# 95    -5.623     1       0.0312       0.51300          0.000005  ...    0.397
# 96    -6.947     1       0.0255       0.22700          0.000189  ...    0.248
# 97    -4.400     1       0.0459       0.00516          0.000000  ...    0.626
# 98    -7.819     1       0.1230       0.04140          0.000000  ...    0.351
# 99    -2.876     0       0.1680       0.08530          0.000000  ...    0.231
#
#       tempo            type                      id  \
# 0   109.997  audio_features  2bgTY4UwhfBYhGT4HUYStN
# 1   166.928  audio_features  4ZtFanR9U6ndgddUvNcjcG
# 2   103.026  audio_features  49gruEYzuJZoy4R2q5xVlT
# 3    90.030  audio_features  4iJyoBOLtHqaGxP12qzhQI
# 4   148.088  audio_features  7MAibcTli4IisCtbHKrGMh
# ..      ...             ...                     ...
# 95  139.931  audio_features  5QS8PNEWbqTEZyQ6e9ZbJf
# 96  147.886  audio_features  3SR6R5XetNfOcVqvUwDkTz
# 97  119.991  audio_features  0QULNNd9z5s35entfiiXoa
# 98   97.033  audio_features  1EXRmdtTA2IEnYGiuw9plD
# 99   74.861  audio_features  1TZv3bujNaYz646eezRE91
#
#                                      uri  \
# 0   spotify:track:2bgTY4UwhfBYhGT4HUYStN
# 1   spotify:track:4ZtFanR9U6ndgddUvNcjcG
# 2   spotify:track:49gruEYzuJZoy4R2q5xVlT
# 3   spotify:track:4iJyoBOLtHqaGxP12qzhQI
# 4   spotify:track:7MAibcTli4IisCtbHKrGMh
# ..                                   ...
# 95  spotify:track:5QS8PNEWbqTEZyQ6e9ZbJf
# 96  spotify:track:3SR6R5XetNfOcVqvUwDkTz
# 97  spotify:track:0QULNNd9z5s35entfiiXoa
# 98  spotify:track:1EXRmdtTA2IEnYGiuw9plD
# 99  spotify:track:1TZv3bujNaYz646eezRE91
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/2bgTY4UwhfBY...
# 1   https://api.spotify.com/v1/tracks/4ZtFanR9U6nd...
# 2   https://api.spotify.com/v1/tracks/49gruEYzuJZo...
# 3   https://api.spotify.com/v1/tracks/4iJyoBOLtHqa...
# 4   https://api.spotify.com/v1/tracks/7MAibcTli4Ii...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/5QS8PNEWbqTE...
# 96  https://api.spotify.com/v1/tracks/3SR6R5XetNfO...
# 97  https://api.spotify.com/v1/tracks/0QULNNd9z5s3...
# 98  https://api.spotify.com/v1/tracks/1EXRmdtTA2IE...
# 99  https://api.spotify.com/v1/tracks/1TZv3bujNaYz...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2bgT...      164442
# 1   https://api.spotify.com/v1/audio-analysis/4ZtF...      178147
# 2   https://api.spotify.com/v1/audio-analysis/49gr...      203064
# 3   https://api.spotify.com/v1/audio-analysis/4iJy...      198082
# 4   https://api.spotify.com/v1/audio-analysis/7MAi...      242096
# ..                                                ...         ...
# 95  https://api.spotify.com/v1/audio-analysis/5QS8...      203373
# 96  https://api.spotify.com/v1/audio-analysis/3SR6...      221240
# 97  https://api.spotify.com/v1/audio-analysis/0QUL...      245626
# 98  https://api.spotify.com/v1/audio-analysis/1EXR...      195454
# 99  https://api.spotify.com/v1/audio-analysis/1TZv...      339506
#
#     time_signature  origin
# 0                4       1
# 1                4       1
# 2                4       1
# 3                4       1
# 4                4       1
# ..             ...     ...
# 95               4       1
# 96               4       1
# 97               4       1
# 98               4       1
# 99               4       1
#
# [100 rows x 21 columns]

# %% [markdown]
# # Removing duplicates

# %%
spotify.drop_duplicates(subset=['uri'], inplace=True, ignore_index=True)
spotify
# Out:
#                                              Title        Artist  \
# 0                                Wild Strawberries          PNAU
# 1                                        Papaoutai       Stromae
# 2     Sweet Dreams (Are Made of This) - Remastered    Eurythmics
# 3                    Rock and Roll - 1990 Remaster  Led Zeppelin
# 4                      Talk Dirty (feat. 2 Chainz)  Jason Derulo
# ...                                            ...           ...
# 9938                                          Yayo  Lana Del Rey
# 9939                                          Yayo  Lana Del Rey
# 9940                          Regret In Your Tears   Nicki Minaj
# 9941                      OBLIVION - Anderex Remix    Riot Shift
# 9942                            I’ll Keep You Safe      Vluestar
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.647   0.933    7    -4.056     1       0.1110      0.000351
# 1            0.733   0.818   10    -7.222     0       0.0859      0.024100
# 2            0.692   0.711    0    -7.498     0       0.0317      0.225000
# 3            0.327   0.895    9    -7.428     1       0.0367      0.000564
# 4            0.760   0.652    6    -7.321     1       0.2320      0.034800
# ...            ...     ...  ...       ...   ...          ...           ...
# 9938         0.506   0.201    3   -12.931     0       0.0294      0.926000
# 9939         0.506   0.201    3   -12.931     0       0.0294      0.926000
# 9940         0.770   0.477    0   -10.972     0       0.0802      0.749000
# 9941         0.329   0.977    8    -4.688     1       0.4230      0.001200
# 9942         0.540   0.341   10   -10.399     0       0.0717      0.802000
#
#       instrumentalness  ...  valence    tempo            type  \
# 0             0.002770  ...    0.332  119.921  audio_features
# 1             0.000000  ...    0.253  116.019  audio_features
# 2             0.000000  ...    0.875  125.135  audio_features
# 3             0.015900  ...    0.898  169.390  audio_features
# 4             0.000000  ...    0.759  100.315  audio_features
# ...                ...  ...      ...      ...             ...
# 9938          0.000411  ...    0.145   71.925  audio_features
# 9939          0.000411  ...    0.145   71.925  audio_features
# 9940          0.208000  ...    0.248  106.128  audio_features
# 9941          0.008310  ...    0.286  161.017  audio_features
# 9942          0.009210  ...    0.283  137.753  audio_features
#
#                           id                                   uri  \
# 0     6pGUGTIaZ1H4jKHIL4Fged  spotify:track:6pGUGTIaZ1H4jKHIL4Fged
# 1     09TcIuH1ZO7i4vicWKoaN2  spotify:track:09TcIuH1ZO7i4vicWKoaN2
# 2     1TfqLAPs4K3s2rJMoCokcS  spotify:track:1TfqLAPs4K3s2rJMoCokcS
# 3     3w2GGz0HjIu9OcWXINRFJR  spotify:track:3w2GGz0HjIu9OcWXINRFJR
# 4     4X4tgBEUiT6WqB2oTJ5ynH  spotify:track:4X4tgBEUiT6WqB2oTJ5ynH
# ...                      ...                                   ...
# 9938  6EfNun62AXVq3on5hqKEWu  spotify:track:6EfNun62AXVq3on5hqKEWu
# 9939  2rldjI2fK6nYwlMgaITluf  spotify:track:2rldjI2fK6nYwlMgaITluf
# 9940  0j8zLbIueSkVqB3Tl6PsjA  spotify:track:0j8zLbIueSkVqB3Tl6PsjA
# 9941  6T4jfMT7vzbpjm8durkojq  spotify:track:6T4jfMT7vzbpjm8durkojq
# 9942  3YfNhioGntblm6ciPsCwC9  spotify:track:3YfNhioGntblm6ciPsCwC9
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6pGUGTIaZ1H4...
# 1     https://api.spotify.com/v1/tracks/09TcIuH1ZO7i...
# 2     https://api.spotify.com/v1/tracks/1TfqLAPs4K3s...
# 3     https://api.spotify.com/v1/tracks/3w2GGz0HjIu9...
# 4     https://api.spotify.com/v1/tracks/4X4tgBEUiT6W...
# ...                                                 ...
# 9938  https://api.spotify.com/v1/tracks/6EfNun62AXVq...
# 9939  https://api.spotify.com/v1/tracks/2rldjI2fK6nY...
# 9940  https://api.spotify.com/v1/tracks/0j8zLbIueSkV...
# 9941  https://api.spotify.com/v1/tracks/6T4jfMT7vzbp...
# 9942  https://api.spotify.com/v1/tracks/3YfNhioGntbl...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6pGU...      235107
# 1     https://api.spotify.com/v1/audio-analysis/09Tc...      232147
# 2     https://api.spotify.com/v1/audio-analysis/1Tfq...      216933
# 3     https://api.spotify.com/v1/audio-analysis/3w2G...      219800
# 4     https://api.spotify.com/v1/audio-analysis/4X4t...      177685
# ...                                                 ...         ...
# 9938  https://api.spotify.com/v1/audio-analysis/6EfN...      321054
# 9939  https://api.spotify.com/v1/audio-analysis/2rld...      321054
# 9940  https://api.spotify.com/v1/audio-analysis/0j8z...      229573
# 9941  https://api.spotify.com/v1/audio-analysis/6T4j...      212633
# 9942  https://api.spotify.com/v1/audio-analysis/3YfN...      140339
#
#       time_signature  origin
# 0                  4       0
# 1                  4       0
# 2                  4       0
# 3                  4       0
# 4                  4       0
# ...              ...     ...
# 9938               4       0
# 9939               4       0
# 9940               4       0
# 9941               4       0
# 9942               4       0
#
# [9943 rows x 21 columns]

# %% [markdown]
# # Concatenate

# %%
concat_top_100_and_spotify = pd.concat([hot_100, spotify], axis = 0, ignore_index = True)
concat_top_100_and_spotify
# Out:
#                           Title  \
# 0                        Butter
# 1                      Good 4 U
# 2                    Levitating
# 3                       Peaches
# 4           Leave The Door Open
# ...                         ...
# 10038                      Yayo
# 10039                      Yayo
# 10040      Regret In Your Tears
# 10041  OBLIVION - Anderex Remix
# 10042        I’ll Keep You Safe
#
#                                                Artist  danceability  energy  \
# 0                                                 BTS         0.759   0.459
# 1                                      Olivia Rodrigo         0.563   0.664
# 2                           Dua Lipa Featuring DaBaby         0.708   0.796
# 3      Justin Bieber Featuring Daniel Caesar & Giveon         0.677   0.696
# 4            Silk Sonic (Bruno Mars & Anderson .Paak)         0.586   0.616
# ...                                               ...           ...     ...
# 10038                                    Lana Del Rey         0.506   0.201
# 10039                                    Lana Del Rey         0.506   0.201
# 10040                                     Nicki Minaj         0.770   0.477
# 10041                                      Riot Shift         0.329   0.977
# 10042                                        Vluestar         0.540   0.341
#
#        key  loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 0        8    -5.187     1       0.0948       0.00323          0.000000  ...
# 1        9    -5.044     1       0.1540       0.33500          0.000000  ...
# 2        6    -4.821     0       0.0610       0.00886          0.000000  ...
# 3        0    -6.181     1       0.1190       0.32100          0.000000  ...
# 4        5    -7.964     1       0.0324       0.18200          0.000000  ...
# ...    ...       ...   ...          ...           ...               ...  ...
# 10038    3   -12.931     0       0.0294       0.92600          0.000411  ...
# 10039    3   -12.931     0       0.0294       0.92600          0.000411  ...
# 10040    0   -10.972     0       0.0802       0.74900          0.208000  ...
# 10041    8    -4.688     1       0.4230       0.00120          0.008310  ...
# 10042   10   -10.399     0       0.0717       0.80200          0.009210  ...
#
#        valence    tempo            type                      id  \
# 0        0.695  109.997  audio_features  2bgTY4UwhfBYhGT4HUYStN
# 1        0.688  166.928  audio_features  4ZtFanR9U6ndgddUvNcjcG
# 2        0.923  103.026  audio_features  49gruEYzuJZoy4R2q5xVlT
# 3        0.464   90.030  audio_features  4iJyoBOLtHqaGxP12qzhQI
# 4        0.719  148.088  audio_features  7MAibcTli4IisCtbHKrGMh
# ...        ...      ...             ...                     ...
# 10038    0.145   71.925  audio_features  6EfNun62AXVq3on5hqKEWu
# 10039    0.145   71.925  audio_features  2rldjI2fK6nYwlMgaITluf
# 10040    0.248  106.128  audio_features  0j8zLbIueSkVqB3Tl6PsjA
# 10041    0.286  161.017  audio_features  6T4jfMT7vzbpjm8durkojq
# 10042    0.283  137.753  audio_features  3YfNhioGntblm6ciPsCwC9
#
#                                         uri  \
# 0      spotify:track:2bgTY4UwhfBYhGT4HUYStN
# 1      spotify:track:4ZtFanR9U6ndgddUvNcjcG
# 2      spotify:track:49gruEYzuJZoy4R2q5xVlT
# 3      spotify:track:4iJyoBOLtHqaGxP12qzhQI
# 4      spotify:track:7MAibcTli4IisCtbHKrGMh
# ...                                     ...
# 10038  spotify:track:6EfNun62AXVq3on5hqKEWu
# 10039  spotify:track:2rldjI2fK6nYwlMgaITluf
# 10040  spotify:track:0j8zLbIueSkVqB3Tl6PsjA
# 10041  spotify:track:6T4jfMT7vzbpjm8durkojq
# 10042  spotify:track:3YfNhioGntblm6ciPsCwC9
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/2bgTY4UwhfBY...
# 1      https://api.spotify.com/v1/tracks/4ZtFanR9U6nd...
# 2      https://api.spotify.com/v1/tracks/49gruEYzuJZo...
# 3      https://api.spotify.com/v1/tracks/4iJyoBOLtHqa...
# 4      https://api.spotify.com/v1/tracks/7MAibcTli4Ii...
# ...                                                  ...
# 10038  https://api.spotify.com/v1/tracks/6EfNun62AXVq...
# 10039  https://api.spotify.com/v1/tracks/2rldjI2fK6nY...
# 10040  https://api.spotify.com/v1/tracks/0j8zLbIueSkV...
# 10041  https://api.spotify.com/v1/tracks/6T4jfMT7vzbp...
# 10042  https://api.spotify.com/v1/tracks/3YfNhioGntbl...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/2bgT...      164442
# 1      https://api.spotify.com/v1/audio-analysis/4ZtF...      178147
# 2      https://api.spotify.com/v1/audio-analysis/49gr...      203064
# 3      https://api.spotify.com/v1/audio-analysis/4iJy...      198082
# 4      https://api.spotify.com/v1/audio-analysis/7MAi...      242096
# ...                                                  ...         ...
# 10038  https://api.spotify.com/v1/audio-analysis/6EfN...      321054
# 10039  https://api.spotify.com/v1/audio-analysis/2rld...      321054
# 10040  https://api.spotify.com/v1/audio-analysis/0j8z...      229573
# 10041  https://api.spotify.com/v1/audio-analysis/6T4j...      212633
# 10042  https://api.spotify.com/v1/audio-analysis/3YfN...      140339
#
#        time_signature  origin
# 0                   4       1
# 1                   4       1
# 2                   4       1
# 3                   4       1
# 4                   4       1
# ...               ...     ...
# 10038               4       0
# 10039               4       0
# 10040               4       0
# 10041               4       0
# 10042               4       0
#
# [10043 rows x 21 columns]

# %% [markdown]
# # Taking numerical variables

# %%
numerical = concat_top_100_and_spotify.copy()

# %%
numerical.drop(['Title', 'Artist', 'type', 'id', 'uri', 'track_href', 'analysis_url',
               'time_signature', 'origin'], axis=1, inplace=True)
numerical
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.759   0.459    8    -5.187     1       0.0948       0.00323
# 1             0.563   0.664    9    -5.044     1       0.1540       0.33500
# 2             0.708   0.796    6    -4.821     0       0.0610       0.00886
# 3             0.677   0.696    0    -6.181     1       0.1190       0.32100
# 4             0.586   0.616    5    -7.964     1       0.0324       0.18200
# ...             ...     ...  ...       ...   ...          ...           ...
# 10038         0.506   0.201    3   -12.931     0       0.0294       0.92600
# 10039         0.506   0.201    3   -12.931     0       0.0294       0.92600
# 10040         0.770   0.477    0   -10.972     0       0.0802       0.74900
# 10041         0.329   0.977    8    -4.688     1       0.4230       0.00120
# 10042         0.540   0.341   10   -10.399     0       0.0717       0.80200
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 0              0.000000    0.0906    0.695  109.997       164442
# 1              0.000000    0.0849    0.688  166.928       178147
# 2              0.000000    0.0668    0.923  103.026       203064
# 3              0.000000    0.4200    0.464   90.030       198082
# 4              0.000000    0.0927    0.719  148.088       242096
# ...                 ...       ...      ...      ...          ...
# 10038          0.000411    0.2530    0.145   71.925       321054
# 10039          0.000411    0.2530    0.145   71.925       321054
# 10040          0.208000    0.1660    0.248  106.128       229573
# 10041          0.008310    0.2980    0.286  161.017       212633
# 10042          0.009210    0.1300    0.283  137.753       140339
#
# [10043 rows x 12 columns]

# %% [markdown]
# # Convert pandas DF to NP array

# %%
numerical_np_array = numerical.to_numpy()
numerical_np_array
# Out:
# array([[7.59000e-01, 4.59000e-01, 8.00000e+00, ..., 6.95000e-01,
#         1.09997e+02, 1.64442e+05],
#        [5.63000e-01, 6.64000e-01, 9.00000e+00, ..., 6.88000e-01,
#         1.66928e+02, 1.78147e+05],
#        [7.08000e-01, 7.96000e-01, 6.00000e+00, ..., 9.23000e-01,
#         1.03026e+02, 2.03064e+05],
#        ...,
#        [7.70000e-01, 4.77000e-01, 0.00000e+00, ..., 2.48000e-01,
#         1.06128e+02, 2.29573e+05],
#        [3.29000e-01, 9.77000e-01, 8.00000e+00, ..., 2.86000e-01,
#         1.61017e+02, 2.12633e+05],
#        [5.40000e-01, 3.41000e-01, 1.00000e+01, ..., 2.83000e-01,
#         1.37753e+02, 1.40339e+05]])

# %% [markdown]
# # standardize

# %%
scaler = StandardScaler().fit(numerical_np_array)
numerical_array_scaled = scaler.transform(numerical_np_array)

numerical_scalled_df = pd.DataFrame(numerical_array_scaled, columns = numerical.columns)
numerical_scalled_df
# Out:
#        danceability    energy       key  loudness      mode  speechiness  \
# 0          0.996282 -1.231372  0.749224  0.453165  0.780511     0.115918
# 1         -0.238658 -0.221006  1.026348  0.495894  0.780511     0.812795
# 2          0.674946  0.429571  0.194977  0.562526 -1.281212    -0.281961
# 3          0.479624 -0.063290 -1.467764  0.156160  0.780511     0.400790
# 4         -0.093742 -0.457580 -0.082146 -0.376597  0.780511    -0.618628
# ...             ...       ...       ...       ...       ...          ...
# 10038     -0.597799 -2.502955 -0.636394 -1.860727 -1.281212    -0.653942
# 10039     -0.597799 -2.502955 -0.636394 -1.860727 -1.281212    -0.653942
# 10040      1.065590 -1.142657 -1.467764 -1.275381 -1.281212    -0.055947
# 10041     -1.713026  1.321651  0.749224  0.602266  0.780511     3.979346
# 10042     -0.383575 -1.812949  1.303471 -1.104170 -1.281212    -0.156005
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 0         -0.685853         -0.408605 -0.649467  0.762846 -0.488981
# 1          0.639010         -0.408605 -0.685018  0.733866  1.613560
# 2         -0.663371         -0.408605 -0.797910  1.706778 -0.746429
# 3          0.583103         -0.408605  1.405033 -0.193506 -1.226390
# 4          0.028032         -0.408605 -0.636369  0.862208  0.917772
# ...             ...               ...       ...       ...       ...
# 10038      2.999059         -0.406826  0.363438 -1.514182 -1.895032
# 10039      2.999059         -0.406826  0.363438 -1.514182 -1.895032
# 10040      2.292242          0.491767 -0.179190 -1.087757 -0.631868
# 10041     -0.693959         -0.372634  0.644107 -0.930435  1.395258
# 10042      2.503888         -0.368738 -0.403725 -0.942855  0.536087
#
#        duration_ms
# 0        -1.277501
# 1        -1.000138
# 2        -0.495866
# 3        -0.596692
# 4         0.294066
# ...            ...
# 10038     1.892025
# 10039     1.892025
# 10040     0.040625
# 10041    -0.302208
# 10042    -1.765300
#
# [10043 rows x 12 columns]

# %%
numerical_scalled_df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  1.004300e+04  1.004300e+04  1.004300e+04  1.004300e+04  1.004300e+04
# mean  -1.013141e-15 -2.490402e-16  1.139076e-16  1.132001e-17 -1.337176e-16
# std    1.000050e+00  1.000050e+00  1.000050e+00  1.000050e+00  1.000050e+00
# min   -3.339241e+00 -3.479363e+00 -1.467764e+00 -9.878673e+00 -1.281212e+00
# 25%   -6.671069e-01 -6.103666e-01 -9.135171e-01 -4.054308e-01 -1.281212e+00
# 50%    4.487418e-02  1.880692e-01 -8.214645e-02  2.302621e-01  7.805109e-01
# 75%    7.190509e-01  7.992175e-01  7.492242e-01  6.648638e-01  7.805109e-01
# max    2.388741e+00  1.430080e+00  1.580595e+00  2.198445e+00  7.805109e-01
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  1.004300e+04  1.004300e+04      1.004300e+04  1.004300e+04
# mean  -1.528201e-16 -1.188601e-16     -3.396002e-17  1.344251e-16
# std    1.000050e+00  1.000050e+00      1.000050e+00  1.000050e+00
# min   -7.422291e-01 -6.987457e-01     -4.086052e-01 -1.139702e+00
# 25%   -5.680099e-01 -6.743122e-01     -4.086052e-01 -6.338739e-01
# 50%   -3.855506e-01 -4.958909e-01     -4.083057e-01 -4.161992e-01
# 75%    8.413488e-02  2.496612e-01     -3.525484e-01  3.915048e-01
# max    1.006525e+01  3.274598e+00      3.885480e+00  4.922756e+00
#
#             valence         tempo   duration_ms
# count  1.004300e+04  1.004300e+04  1.004300e+04
# mean   9.905007e-17 -2.023451e-16 -8.490006e-17
# std    1.000050e+00  1.000050e+00  1.000050e+00
# min   -2.006020e+00 -2.934097e+00 -3.322600e+00
# 25%   -7.689728e-01 -7.471127e-01 -6.597845e-01
# 50%   -1.962343e-02 -3.185417e-03 -1.145808e-01
# 75%    7.918267e-01  5.632312e-01  5.603490e-01
# max    1.984162e+00  3.482398e+00  7.394070e+00

# %% [markdown]
# # Clustering with K-Means

# %%
kmeans = KMeans(n_clusters=7, random_state=1234)
kmeans.fit(numerical_scalled_df)
# Out:
# KMeans(n_clusters=7, random_state=1234)

# %%
with open('D:\Data Science\Ironhack\Week 3\Project_song_recomender\model\Kmean.pickle', 'wb') as f:
    pickle.dump(kmeans, f)

# %% [markdown]
# # Making clusters

# %%
clusters = kmeans.predict(numerical_scalled_df)
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    1254
# 1    1750
# 2    2222
# 3     592
# 4     802
# 5    2712
# 6     711
# dtype: int64

# %% [markdown]
# # Plaing with the parameters

# %%
kmeans = KMeans(n_clusters=7,
                init="random",
                n_init=3,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=2,
                tol=0,
                algorithm="full",
                random_state=1234)
kmeans.fit(numerical_scalled_df)
print(kmeans.inertia_)
# Out:
# 80261.4402100813

# %% [markdown]
# # Choosing K

# %%
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(numerical_scalled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# # Silouhete method

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(numerical_scalled_df)
    silhouette.append(silhouette_score(numerical_scalled_df, kmeans.predict(numerical_scalled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %% [markdown]
# # Testing inertia scores

# %%
kmeans = KMeans(n_clusters=7, random_state=1234)
kmeans.fit(numerical_scalled_df)

final_cluster = kmeans.predict(numerical_scalled_df)
pd.Series(final_cluster).value_counts().sort_index()
# Out:
# 0    1254
# 1    1750
# 2    2222
# 3     592
# 4     802
# 5    2712
# 6     711
# dtype: int64

# %% [markdown]
# # Saving model

# %%
with open('D:\Data Science\Ironhack\Week 3\Project_song_recomender\model\scaler.pickle', 'wb') as f:
    pickle.dump(scaler, f)

# %%
with open('D:\Data Science\Ironhack\Week 3\Project_song_recomender\model\Kmean.pickle', 'wb') as f:
    pickle.dump(kmeans, f)

# %% [markdown]
# # Updating internal DB

# %%
clustered_df = pd.DataFrame(numerical_scalled_df)
clustered_df["cluster"] = final_cluster
clustered_df['origin'] = concat_top_100_and_spotify['origin']
clustered_df['title'] = concat_top_100_and_spotify['Title']
clustered_df['artist'] = concat_top_100_and_spotify['Artist']
clustered_df
# Out:
#        danceability    energy       key  loudness      mode  speechiness  \
# 0          0.996282 -1.231372  0.749224  0.453165  0.780511     0.115918
# 1         -0.238658 -0.221006  1.026348  0.495894  0.780511     0.812795
# 2          0.674946  0.429571  0.194977  0.562526 -1.281212    -0.281961
# 3          0.479624 -0.063290 -1.467764  0.156160  0.780511     0.400790
# 4         -0.093742 -0.457580 -0.082146 -0.376597  0.780511    -0.618628
# ...             ...       ...       ...       ...       ...          ...
# 10038     -0.597799 -2.502955 -0.636394 -1.860727 -1.281212    -0.653942
# 10039     -0.597799 -2.502955 -0.636394 -1.860727 -1.281212    -0.653942
# 10040      1.065590 -1.142657 -1.467764 -1.275381 -1.281212    -0.055947
# 10041     -1.713026  1.321651  0.749224  0.602266  0.780511     3.979346
# 10042     -0.383575 -1.812949  1.303471 -1.104170 -1.281212    -0.156005
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 0         -0.685853         -0.408605 -0.649467  0.762846 -0.488981
# 1          0.639010         -0.408605 -0.685018  0.733866  1.613560
# 2         -0.663371         -0.408605 -0.797910  1.706778 -0.746429
# 3          0.583103         -0.408605  1.405033 -0.193506 -1.226390
# 4          0.028032         -0.408605 -0.636369  0.862208  0.917772
# ...             ...               ...       ...       ...       ...
# 10038      2.999059         -0.406826  0.363438 -1.514182 -1.895032
# 10039      2.999059         -0.406826  0.363438 -1.514182 -1.895032
# 10040      2.292242          0.491767 -0.179190 -1.087757 -0.631868
# 10041     -0.693959         -0.372634  0.644107 -0.930435  1.395258
# 10042      2.503888         -0.368738 -0.403725 -0.942855  0.536087
#
#        duration_ms  cluster  origin                     title  \
# 0        -1.277501        5       1                    Butter
# 1        -1.000138        1       1                  Good 4 U
# 2        -0.495866        2       1                Levitating
# 3        -0.596692        5       1                   Peaches
# 4         0.294066        5       1       Leave The Door Open
# ...            ...      ...     ...                       ...
# 10038     1.892025        0       0                      Yayo
# 10039     1.892025        0       0                      Yayo
# 10040     0.040625        0       0      Regret In Your Tears
# 10041    -0.302208        6       0  OBLIVION - Anderex Remix
# 10042    -1.765300        0       0        I’ll Keep You Safe
#
#                                                artist
# 0                                                 BTS
# 1                                      Olivia Rodrigo
# 2                           Dua Lipa Featuring DaBaby
# 3      Justin Bieber Featuring Daniel Caesar & Giveon
# 4            Silk Sonic (Bruno Mars & Anderson .Paak)
# ...                                               ...
# 10038                                    Lana Del Rey
# 10039                                    Lana Del Rey
# 10040                                     Nicki Minaj
# 10041                                      Riot Shift
# 10042                                        Vluestar
#
# [10043 rows x 16 columns]

# %% [markdown]
# # Reordering clustered df

# %%
clustered_df = clustered_df[["title", "artist", "cluster", 'origin', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']]
clustered_df
# Out:
#                           title  \
# 0                        Butter
# 1                      Good 4 U
# 2                    Levitating
# 3                       Peaches
# 4           Leave The Door Open
# ...                         ...
# 10038                      Yayo
# 10039                      Yayo
# 10040      Regret In Your Tears
# 10041  OBLIVION - Anderex Remix
# 10042        I’ll Keep You Safe
#
#                                                artist  cluster  origin  \
# 0                                                 BTS        5       1
# 1                                      Olivia Rodrigo        1       1
# 2                           Dua Lipa Featuring DaBaby        2       1
# 3      Justin Bieber Featuring Daniel Caesar & Giveon        5       1
# 4            Silk Sonic (Bruno Mars & Anderson .Paak)        5       1
# ...                                               ...      ...     ...
# 10038                                    Lana Del Rey        0       0
# 10039                                    Lana Del Rey        0       0
# 10040                                     Nicki Minaj        0       0
# 10041                                      Riot Shift        6       0
# 10042                                        Vluestar        0       0
#
#        danceability    energy       key  loudness      mode  speechiness  \
# 0          0.996282 -1.231372  0.749224  0.453165  0.780511     0.115918
# 1         -0.238658 -0.221006  1.026348  0.495894  0.780511     0.812795
# 2          0.674946  0.429571  0.194977  0.562526 -1.281212    -0.281961
# 3          0.479624 -0.063290 -1.467764  0.156160  0.780511     0.400790
# 4         -0.093742 -0.457580 -0.082146 -0.376597  0.780511    -0.618628
# ...             ...       ...       ...       ...       ...          ...
# 10038     -0.597799 -2.502955 -0.636394 -1.860727 -1.281212    -0.653942
# 10039     -0.597799 -2.502955 -0.636394 -1.860727 -1.281212    -0.653942
# 10040      1.065590 -1.142657 -1.467764 -1.275381 -1.281212    -0.055947
# 10041     -1.713026  1.321651  0.749224  0.602266  0.780511     3.979346
# 10042     -0.383575 -1.812949  1.303471 -1.104170 -1.281212    -0.156005
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 0         -0.685853         -0.408605 -0.649467  0.762846 -0.488981
# 1          0.639010         -0.408605 -0.685018  0.733866  1.613560
# 2         -0.663371         -0.408605 -0.797910  1.706778 -0.746429
# 3          0.583103         -0.408605  1.405033 -0.193506 -1.226390
# 4          0.028032         -0.408605 -0.636369  0.862208  0.917772
# ...             ...               ...       ...       ...       ...
# 10038      2.999059         -0.406826  0.363438 -1.514182 -1.895032
# 10039      2.999059         -0.406826  0.363438 -1.514182 -1.895032
# 10040      2.292242          0.491767 -0.179190 -1.087757 -0.631868
# 10041     -0.693959         -0.372634  0.644107 -0.930435  1.395258
# 10042      2.503888         -0.368738 -0.403725 -0.942855  0.536087
#
#        duration_ms
# 0        -1.277501
# 1        -1.000138
# 2        -0.495866
# 3        -0.596692
# 4         0.294066
# ...            ...
# 10038     1.892025
# 10039     1.892025
# 10040     0.040625
# 10041    -0.302208
# 10042    -1.765300
#
# [10043 rows x 16 columns]

# %% [markdown]
# # Updating smaller names

# %%
clustered_df['title'] = clustered_df['title'].str.lower()
clustered_df['artist'] = clustered_df['artist'].str.lower()
clustered_df
# Out:
#                           title  \
# 0                        butter
# 1                      good 4 u
# 2                    levitating
# 3                       peaches
# 4           leave the door open
# ...                         ...
# 10038                      yayo
# 10039                      yayo
# 10040      regret in your tears
# 10041  oblivion - anderex remix
# 10042        i’ll keep you safe
#
#                                                artist  cluster  origin  \
# 0                                                 bts        5       1
# 1                                      olivia rodrigo        1       1
# 2                           dua lipa featuring dababy        2       1
# 3      justin bieber featuring daniel caesar & giveon        5       1
# 4            silk sonic (bruno mars & anderson .paak)        5       1
# ...                                               ...      ...     ...
# 10038                                    lana del rey        0       0
# 10039                                    lana del rey        0       0
# 10040                                     nicki minaj        0       0
# 10041                                      riot shift        6       0
# 10042                                        vluestar        0       0
#
#        danceability    energy       key  loudness      mode  speechiness  \
# 0          0.996282 -1.231372  0.749224  0.453165  0.780511     0.115918
# 1         -0.238658 -0.221006  1.026348  0.495894  0.780511     0.812795
# 2          0.674946  0.429571  0.194977  0.562526 -1.281212    -0.281961
# 3          0.479624 -0.063290 -1.467764  0.156160  0.780511     0.400790
# 4         -0.093742 -0.457580 -0.082146 -0.376597  0.780511    -0.618628
# ...             ...       ...       ...       ...       ...          ...
# 10038     -0.597799 -2.502955 -0.636394 -1.860727 -1.281212    -0.653942
# 10039     -0.597799 -2.502955 -0.636394 -1.860727 -1.281212    -0.653942
# 10040      1.065590 -1.142657 -1.467764 -1.275381 -1.281212    -0.055947
# 10041     -1.713026  1.321651  0.749224  0.602266  0.780511     3.979346
# 10042     -0.383575 -1.812949  1.303471 -1.104170 -1.281212    -0.156005
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 0         -0.685853         -0.408605 -0.649467  0.762846 -0.488981
# 1          0.639010         -0.408605 -0.685018  0.733866  1.613560
# 2         -0.663371         -0.408605 -0.797910  1.706778 -0.746429
# 3          0.583103         -0.408605  1.405033 -0.193506 -1.226390
# 4          0.028032         -0.408605 -0.636369  0.862208  0.917772
# ...             ...               ...       ...       ...       ...
# 10038      2.999059         -0.406826  0.363438 -1.514182 -1.895032
# 10039      2.999059         -0.406826  0.363438 -1.514182 -1.895032
# 10040      2.292242          0.491767 -0.179190 -1.087757 -0.631868
# 10041     -0.693959         -0.372634  0.644107 -0.930435  1.395258
# 10042      2.503888         -0.368738 -0.403725 -0.942855  0.536087
#
#        duration_ms
# 0        -1.277501
# 1        -1.000138
# 2        -0.495866
# 3        -0.596692
# 4         0.294066
# ...            ...
# 10038     1.892025
# 10039     1.892025
# 10040     0.040625
# 10041    -0.302208
# 10042    -1.765300
#
# [10043 rows x 16 columns]

# %% [markdown]
# # Exporting model's df to csv

# %%
# defining file name, type and directory to be exported

file_name = 'clustered_df.csv'
saving_path = r'D:\Data Science\Ironhack\Week 3\Project_song_recomender\data\{}'.format(file_name)



clustered_df.to_csv(saving_path)
